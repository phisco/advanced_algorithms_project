# %%
f = open("time_optimized_0_100.txt")
l=[]
for line in f:
    l.append([w for w in line.replace("\t", " ").replace("\n", "").split(" ") if w != ''])
f.close()
# l[:3]

# %%
l
# Out:
# [['0__0.xml', '0'],
#  ['1__0.xml', '0'],
#  ['2_0.000000_0.xml', '4.0K'],
#  ['Tarjan',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000002s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000002s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '2'],
#  ['Correct:', '1'],
#  ['2_0.500000_2.xml', '4.0K'],
#  ['Tarjan',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000002s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['2_1.000000_2.xml', '4.0K'],
#  ['Tarjan',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['3_0.000000_0.xml', '4.0K'],
#  ['Tarjan',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000002s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000002s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['3_0.166667_1.xml', '4.0K'],
#  ['Tarjan',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['3_0.333333_2.xml', '4.0K'],
#  ['Tarjan',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['3_0.500000_3.xml', '4.0K'],
#  ['Tarjan',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '2'],
#  ['Correct:', '1'],
#  ['3_0.666667_4.xml', '4.0K'],
#  ['Tarjan',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['3_0.833333_4.xml', '4.0K'],
#  ['Tarjan',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['3_1.000000_4.xml', '4.0K'],
#  ['Tarjan',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['4_0.000000_0.xml', '4.0K'],
#  ['Tarjan',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000002s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '4'],
#  ['Correct:', '1'],
#  ['4_0.083333_1.xml', '4.0K'],
#  ['Tarjan',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '4'],
#  ['Correct:', '1'],
#  ['4_0.166667_2.xml', '4.0K'],
#  ['Tarjan',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '4'],
#  ['Correct:', '1'],
#  ['4_0.250000_4.xml', '4.0K'],
#  ['Tarjan',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['4_0.333333_4.xml', '4.0K'],
#  ['Tarjan',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['4_0.416667_5.xml', '4.0K'],
#  ['Tarjan',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['4_0.500000_6.xml', '4.0K'],
#  ['Tarjan',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['4_0.583333_7.xml', '4.0K'],
#  ['Tarjan',
#   '0.000009s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['4_0.666667_8.xml', '4.0K'],
#  ['Tarjan',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['4_0.750000_8.xml', '4.0K'],
#  ['Tarjan',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['4_0.833333_8.xml', '4.0K'],
#  ['Tarjan',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['4_0.916667_8.xml', '4.0K'],
#  ['Tarjan',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['4_1.000000_8.xml', '4.0K'],
#  ['Tarjan',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.000000_0.xml', '4.0K'],
#  ['Tarjan',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000002s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['5_0.050000_1.xml', '4.0K'],
#  ['Tarjan',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['5_0.100000_2.xml', '4.0K'],
#  ['Tarjan',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['5_0.150000_3.xml', '4.0K'],
#  ['Tarjan',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['5_0.200000_5.xml', '4.0K'],
#  ['Tarjan',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['5_0.250000_6.xml', '4.0K'],
#  ['Tarjan',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['5_0.300000_6.xml', '4.0K'],
#  ['Tarjan',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['5_0.350000_7.xml', '4.0K'],
#  ['Tarjan',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['5_0.400000_8.xml', '4.0K'],
#  ['Tarjan',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['5_0.450000_9.xml', '4.0K'],
#  ['Tarjan',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.500000_9.xml', '4.0K'],
#  ['Tarjan',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.550000_9.xml', '4.0K'],
#  ['Tarjan',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.600000_11.xml', '4.0K'],
#  ['Tarjan',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.650000_11.xml', '4.0K'],
#  ['Tarjan',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.700000_12.xml', '4.0K'],
#  ['Tarjan',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000009s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.750000_13.xml', '4.0K'],
#  ['Tarjan',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.800000_13.xml', '4.0K'],
#  ['Tarjan',
#   '0.000016s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000009s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.850000_14.xml', '4.0K'],
#  ['Tarjan',
#   '0.000016s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000009s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.900000_15.xml', '4.0K'],
#  ['Tarjan',
#   '0.000020s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_0.950000_16.xml', '4.0K'],
#  ['Tarjan',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['5_1.000000_16.xml', '4.0K'],
#  ['Tarjan',
#   '0.000022s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.000000_0.xml', '4.0K'],
#  ['Tarjan',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.033333_1.xml', '4.0K'],
#  ['Tarjan',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000003s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.066667_2.xml', '4.0K'],
#  ['Tarjan',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.100000_3.xml', '4.0K'],
#  ['Tarjan',
#   '0.000009s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.133333_4.xml', '4.0K'],
#  ['Tarjan',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.166667_5.xml', '4.0K'],
#  ['Tarjan',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.200000_6.xml', '4.0K'],
#  ['Tarjan',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.233333_7.xml', '4.0K'],
#  ['Tarjan',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.266667_7.xml', '4.0K'],
#  ['Tarjan',
#   '0.000019s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.300000_8.xml', '4.0K'],
#  ['Tarjan',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.333333_8.xml', '4.0K'],
#  ['Tarjan',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['6_0.366667_9.xml', '4.0K'],
#  ['Tarjan',
#   '0.000015s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000009s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['6_0.400000_10.xml', '4.0K'],
#  ['Tarjan',
#   '0.000016s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['6_0.433333_11.xml', '4.0K'],
#  ['Tarjan',
#   '0.000019s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '2'],
#  ['Correct:', '1'],
#  ['6_0.466667_12.xml', '4.0K'],
#  ['Tarjan',
#   '0.000017s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '2'],
#  ['Correct:', '1'],
#  ['6_0.500000_14.xml', '4.0K'],
#  ['Tarjan',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.533333_14.xml', '4.0K'],
#  ['Tarjan',
#   '0.000016s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.566667_14.xml', '4.0K'],
#  ['Tarjan',
#   '0.000017s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.600000_14.xml', '4.0K'],
#  ['Tarjan',
#   '0.000141s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000593s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000186s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.633333_15.xml', '4.0K'],
#  ['Tarjan',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.666667_15.xml', '4.0K'],
#  ['Tarjan',
#   '0.000019s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.700000_15.xml', '4.0K'],
#  ['Tarjan',
#   '0.000020s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000009s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.733333_16.xml', '4.0K'],
#  ['Tarjan',
#   '0.000019s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.766667_16.xml', '4.0K'],
#  ['Tarjan',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.800000_17.xml', '4.0K'],
#  ['Tarjan',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.833333_18.xml', '4.0K'],
#  ['Tarjan',
#   '0.000023s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.866667_19.xml', '4.0K'],
#  ['Tarjan',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.900000_19.xml', '4.0K'],
#  ['Tarjan',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.933333_19.xml', '4.0K'],
#  ['Tarjan',
#   '0.000022s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_0.966667_19.xml', '4.0K'],
#  ['Tarjan',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['6_1.000000_20.xml', '4.0K'],
#  ['Tarjan',
#   '0.000113s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000189s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['7_0.000000_0.xml', '4.0K'],
#  ['Tarjan',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '7'],
#  ['Correct:', '1'],
#  ['7_0.023810_1.xml', '4.0K'],
#  ['Tarjan',
#   '0.000007s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '7'],
#  ['Correct:', '1'],
#  ['7_0.047619_2.xml', '4.0K'],
#  ['Tarjan',
#   '0.000017s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '7'],
#  ['Correct:', '1'],
#  ['7_0.071429_3.xml', '4.0K'],
#  ['Tarjan',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000004s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '7'],
#  ['Correct:', '1'],
#  ['7_0.095238_4.xml', '4.0K'],
#  ['Tarjan',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000005s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '7'],
#  ['Correct:', '1'],
#  ['7_0.119048_5.xml', '4.0K'],
#  ['Tarjan',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000006s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '7'],
#  ['Correct:', '1'],
#  ['7_0.142857_6.xml', '4.0K'],
#  ['Tarjan',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '7'],
#  ['Correct:', '1'],
#  ['7_0.166667_8.xml', '4.0K'],
#  ['Tarjan',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000008s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '7'],
#  ['Correct:', '1'],
#  ['7_0.190476_9.xml', '4.0K'],
#  ['Tarjan',
#   '0.000015s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000009s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '7'],
#  ['Correct:', '1'],
#  ['7_0.214286_10.xml', '4.0K'],
#  ['Tarjan',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['7_0.238095_11.xml', '4.0K'],
#  ['Tarjan',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['7_0.261905_11.xml', '4.0K'],
#  ['Tarjan',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000009s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['7_0.285714_11.xml', '4.0K'],
#  ['Tarjan',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '6'],
#  ['Correct:', '1'],
#  ['7_0.309524_12.xml', '4.0K'],
#  ['Tarjan',
#   '0.000020s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['7_0.333333_13.xml', '4.0K'],
#  ['Tarjan',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['7_0.357143_13.xml', '4.0K'],
#  ['Tarjan',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000010s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['7_0.380952_14.xml', '4.0K'],
#  ['Tarjan',
#   '0.000019s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '4'],
#  ['Correct:', '1'],
#  ['7_0.404762_14.xml', '4.0K'],
#  ['Tarjan',
#   '0.000020s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '4'],
#  ['Correct:', '1'],
#  ['7_0.428571_14.xml', '4.0K'],
#  ['Tarjan',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000011s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '4'],
#  ['Correct:', '1'],
#  ['7_0.452381_16.xml', '4.0K'],
#  ['Tarjan',
#   '0.000020s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000013s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000012s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '4'],
#  ['Correct:', '1'],
#  ['7_0.476190_16.xml', '4.0K'],
#  ['Tarjan',
#   '0.000023s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '4'],
#  ['Correct:', '1'],
#  ['7_0.500000_16.xml', '4.0K'],
#  ['Tarjan',
#   '0.000022s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
# ...
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000020s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['8_0.303571_15.xml', '4.0K'],
#  ['Tarjan',
#   '0.000025s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000020s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['8_0.321429_15.xml', '4.0K'],
#  ['Tarjan',
#   '0.000030s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000020s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['8_0.339286_16.xml', '4.0K'],
#  ['Tarjan',
#   '0.000027s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000022s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['8_0.357143_17.xml', '4.0K'],
#  ['Tarjan',
#   '0.000029s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000014s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000017s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '5'],
#  ['Correct:', '1'],
#  ['8_0.375000_18.xml', '4.0K'],
#  ['Tarjan',
#   '0.000032s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000024s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000023s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['8_0.392857_19.xml', '4.0K'],
#  ['Tarjan',
#   '0.000027s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000019s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000019s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '3'],
#  ['Correct:', '1'],
#  ['8_0.410714_20.xml', '4.0K'],
#  ['Tarjan',
#   '0.000038s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000016s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '2'],
#  ['Correct:', '1'],
#  ['8_0.428571_20.xml', '4.0K'],
#  ['Tarjan',
#   '0.000035s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000030s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000028s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '2'],
#  ['Correct:', '1'],
#  ['8_0.446429_21.xml', '4.0K'],
#  ['Tarjan',
#   '0.000036s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000025s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000025s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.464286_22.xml', '4.0K'],
#  ['Tarjan',
#   '0.000035s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000016s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.482143_22.xml', '4.0K'],
#  ['Tarjan',
#   '0.000036s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000027s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000025s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.500000_23.xml', '4.0K'],
#  ['Tarjan',
#   '0.000033s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000022s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.517857_23.xml', '4.0K'],
#  ['Tarjan',
#   '0.000033s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000042s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.535714_24.xml', '4.0K'],
#  ['Tarjan',
#   '0.000029s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000025s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000018s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.553571_25.xml', '4.0K'],
#  ['Tarjan',
#   '0.000031s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000021s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000029s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.571429_26.xml', '4.0K'],
#  ['Tarjan',
#   '0.000036s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000027s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000020s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.589286_27.xml', '4.0K'],
#  ['Tarjan',
#   '0.000032s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000022s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000022s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.607143_28.xml', '4.0K'],
#  ['Tarjan',
#   '0.000034s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000022s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000019s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.625000_30.xml', '4.0K'],
#  ['Tarjan',
#   '0.000051s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000040s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000037s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.642857_31.xml', '4.0K'],
#  ['Tarjan',
#   '0.000044s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000095s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000022s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.660714_32.xml', '4.0K'],
#  ['Tarjan',
#   '0.000046s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000027s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000023s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.678571_33.xml', '4.0K'],
#  ['Tarjan',
#   '0.000045s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000038s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000036s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.696429_33.xml', '4.0K'],
#  ['Tarjan',
#   '0.000045s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000034s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000032s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.714286_34.xml', '4.0K'],
#  ['Tarjan',
#   '0.000039s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000028s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000036s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.732143_34.xml', '4.0K'],
#  ['Tarjan',
#   '0.000040s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000026s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000024s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.750000_36.xml', '4.0K'],
#  ['Tarjan',
#   '0.000039s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000032s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000024s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.767857_37.xml', '4.0K'],
#  ['Tarjan',
#   '0.000040s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000035s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000040s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.785714_37.xml', '4.0K'],
#  ['Tarjan',
#   '0.000049s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000043s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000040s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.803571_37.xml', '4.0K'],
#  ['Tarjan',
#   '0.000047s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000041s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000039s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.821429_38.xml', '4.0K'],
#  ['Tarjan',
#   '0.000037s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000027s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000023s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.839286_39.xml', '4.0K'],
#  ['Tarjan',
#   '0.000037s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.000027s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Pearce',
#   '0.000025s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['8_0.857143_40.xml', '4.0K'],
#  ['Tarjan',
#   '0.000033s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ...]

# %%
ll = []
i=0
['Tarjan',
  '0.000004s',
  'wall,',
  '0.000000s',
  'user',
  '+',
  '0.000000s',
  'system',
  '=',
  '0.000000s',
  'CPU',
  '(n/a%)']
while i< len(l):
    if "__" in l[i][0]:
        i+=1
    else:
        try:
            v, p, e = l[i][0][:-4].split("_")
            ll.append([int(v), float(p), int(e), float(l[i+1][1][:-1]), float(l[i+2][1][:-1]), float(l[i+3][1][:-1]), int(l[i+4][1]), int(l[i+5][1])])
        except:
            print(l[i][0][:-4].split("_"))
        i+=6
ll[:3]
# Out:
# [[2, 0.0, 0, 4e-06, 2e-06, 2e-06, 2, 1],
#  [2, 0.5, 2, 4e-06, 3e-06, 2e-06, 1, 1],
#  [2, 1.0, 2, 5e-06, 3e-06, 3e-06, 1, 1]]

# %%
import csv
f = open("time_optimized_0_100.csv", "w")
f.write("vertices,percentage,edges,tarjan,nuutila,pearce,components,correct\n")
w = csv.writer(f)
w.writerows(ll)
f.close()

# %%
import pandas as pd

# %%
t = pd.read_csv("time_optimized_0_100.csv")
#t = t[["vertices","percentage","edges", "tarjan", "nuutila", "pearce"]].groupby(by=["vertices","percentage","edges"], as_index=False).mean()

# %%
t["v+e"]=t["vertices"]+t["edges"]

# %%
#for n in ["tarjan", "nuutila", "pearce"]:
#    t[n] = t[n]/t["v+e"]

# %%
t.describe()
# Out:
#            vertices    percentage         edges        tarjan       nuutila  \
# count  41699.000000  41699.000000  41699.000000  41699.000000  41699.000000
# mean      37.985899      0.500000    561.432768      0.002168      0.002664
# std        9.690010      0.289024    386.363738      0.001596      0.002093
# min        2.000000      0.000000      0.000000      0.000004      0.000002
# 25%       32.000000      0.249898    232.000000      0.000832      0.000878
# 50%       40.000000      0.500000    501.000000      0.001872      0.002173
# 75%       46.000000      0.750102    848.000000      0.003257      0.004131
# max       50.000000      1.000000   1576.000000      0.018231      0.022179
#
#              pearce    components  correct           v+e
# count  41699.000000  41699.000000  41699.0  41699.000000
# mean       0.002308      3.040097      1.0    599.418667
# std        0.001719      7.460814      0.0    392.473545
# min        0.000002      1.000000      1.0      2.000000
# 25%        0.000881      1.000000      1.0    265.000000
# 50%        0.001953      1.000000      1.0    539.000000
# 75%        0.003478      1.000000      1.0    891.000000
# max        0.019115     50.000000      1.0   1626.000000

# %%
t[t["v+e"]>25200]
# Out:
# Empty DataFrame
# Columns: [vertices, percentage, edges, tarjan, nuutila, pearce, components, correct, v+e]
# Index: []

# %%
t = t.sort_values(by=["v+e","vertices","edges"])
t.plot(x="v+e", y=["tarjan","nuutila","pearce"],figsize=(20,20), subplots=True)
# Out:
# /usr/lib64/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fde1cb2e2e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fde1cb43e48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fde1c5847b8>],
#       dtype=object)

# %%
from scipy.interpolate import griddata
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
df=t
x1 = np.linspace(df['vertices'].min(), df['vertices'].max(), len(df['vertices'].unique()))
y1 = np.linspace(df['edges'].min(), df['edges'].max(), len(df['edges'].unique()))

"""
x, y via meshgrid for vectorized evaluation of
2 scalar/vector fields over 2-D grids, given
one-dimensional coordinate arrays x1, x2,..., xn.
"""

x2, y2 = np.meshgrid(x1, y1)

# Interpolate unstructured D-dimensional data.
z2 = griddata((df['vertices'], df['edges']), df['tarjan'], (x2, y2), method='cubic')

# Ready to plot
fig = plt.figure(figsize=(20,20))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(x2, y2, z2, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
#ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title('Meshgrid Created from 3 1D Arrays')

plt.show()

#Modified example using <code>DataFrame</code> input
# Out:
# /usr/lib64/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /usr/lib64/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# /usr/lib64/python3.6/site-packages/matplotlib/colors.py:489: RuntimeWarning: invalid value encountered in less
#   np.copyto(xa, -1, where=xa < 0.0)

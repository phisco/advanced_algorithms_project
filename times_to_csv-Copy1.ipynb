# %%
f = open("time.txt")
l=[]
for line in f:
    l.append([w for w in line.replace("\t", " ").replace("\n", "").split(" ") if w != ''])
f.close()
# l[:3]

# %%
l
# Out:
# [['100_0.000000_0.xml', '4.0K'],
#  ['Tarjan',
#   '0.005653s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Nuutila',
#   '0.005533s',
#   'wall,',
#   '0.010000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.010000s',
#   'CPU',
#   '(180.7%)'],
#  ['Pearce',
#   '0.005335s',
#   'wall,',
#   '0.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.000000s',
#   'CPU',
#   '(n/a%)'],
#  ['Components:', '100'],
#  ['Correct:', '1'],
#  ['100_0.010101_101.xml', '12K'],
#  ['Tarjan',
#   '0.024712s',
#   'wall,',
#   '0.030000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.030000s',
#   'CPU',
#   '(121.4%)'],
#  ['Nuutila',
#   '0.028359s',
#   'wall,',
#   '0.020000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.020000s',
#   'CPU',
#   '(70.5%)'],
#  ['Pearce',
#   '0.028065s',
#   'wall,',
#   '0.030000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.030000s',
#   'CPU',
#   '(106.9%)'],
#  ['Components:', '96'],
#  ['Correct:', '1'],
#  ['100_0.020202_200.xml', '16K'],
#  ['Tarjan',
#   '0.048088s',
#   'wall,',
#   '0.050000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.050000s',
#   'CPU',
#   '(104.0%)'],
#  ['Nuutila',
#   '0.048199s',
#   'wall,',
#   '0.050000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.050000s',
#   'CPU',
#   '(103.7%)'],
#  ['Pearce',
#   '0.048177s',
#   'wall,',
#   '0.040000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.040000s',
#   'CPU',
#   '(83.0%)'],
#  ['Components:', '41'],
#  ['Correct:', '1'],
#  ['100_0.030303_297.xml', '24K'],
#  ['Tarjan',
#   '0.066904s',
#   'wall,',
#   '0.070000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.070000s',
#   'CPU',
#   '(104.6%)'],
#  ['Nuutila',
#   '0.067081s',
#   'wall,',
#   '0.070000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.070000s',
#   'CPU',
#   '(104.4%)'],
#  ['Pearce',
#   '0.066668s',
#   'wall,',
#   '0.060000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.060000s',
#   'CPU',
#   '(90.0%)'],
#  ['Components:', '12'],
#  ['Correct:', '1'],
#  ['100_0.040404_394.xml', '28K'],
#  ['Tarjan',
#   '0.086767s',
#   'wall,',
#   '0.080000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.080000s',
#   'CPU',
#   '(92.2%)'],
#  ['Nuutila',
#   '0.086095s',
#   'wall,',
#   '0.090000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.090000s',
#   'CPU',
#   '(104.5%)'],
#  ['Pearce',
#   '0.086006s',
#   'wall,',
#   '0.090000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.090000s',
#   'CPU',
#   '(104.6%)'],
#  ['Components:', '2'],
#  ['Correct:', '1'],
#  ['100_0.050505_490.xml', '32K'],
#  ['Tarjan',
#   '0.105373s',
#   'wall,',
#   '0.100000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.100000s',
#   'CPU',
#   '(94.9%)'],
#  ['Nuutila',
#   '0.103240s',
#   'wall,',
#   '0.110000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.110000s',
#   'CPU',
#   '(106.5%)'],
#  ['Pearce',
#   '0.089729s',
#   'wall,',
#   '0.090000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.090000s',
#   'CPU',
#   '(100.3%)'],
#  ['Components:', '2'],
#  ['Correct:', '1'],
#  ['100_0.060606_583.xml', '40K'],
#  ['Tarjan',
#   '0.122168s',
#   'wall,',
#   '0.120000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.120000s',
#   'CPU',
#   '(98.2%)'],
#  ['Nuutila',
#   '0.122567s',
#   'wall,',
#   '0.120000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.120000s',
#   'CPU',
#   '(97.9%)'],
#  ['Pearce',
#   '0.119254s',
#   'wall,',
#   '0.120000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.120000s',
#   'CPU',
#   '(100.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.070707_680.xml', '44K'],
#  ['Tarjan',
#   '0.122277s',
#   'wall,',
#   '0.120000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.120000s',
#   'CPU',
#   '(98.1%)'],
#  ['Nuutila',
#   '0.124774s',
#   'wall,',
#   '0.130000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.130000s',
#   'CPU',
#   '(104.2%)'],
#  ['Pearce',
#   '0.140871s',
#   'wall,',
#   '0.140000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.140000s',
#   'CPU',
#   '(99.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.080808_773.xml', '48K'],
#  ['Tarjan',
#   '0.156534s',
#   'wall,',
#   '0.150000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.150000s',
#   'CPU',
#   '(95.8%)'],
#  ['Nuutila',
#   '0.158428s',
#   'wall,',
#   '0.160000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.160000s',
#   'CPU',
#   '(101.0%)'],
#  ['Pearce',
#   '0.156926s',
#   'wall,',
#   '0.160000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.160000s',
#   'CPU',
#   '(102.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.090909_864.xml', '56K'],
#  ['Tarjan',
#   '0.173586s',
#   'wall,',
#   '0.180000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.180000s',
#   'CPU',
#   '(103.7%)'],
#  ['Nuutila',
#   '0.174159s',
#   'wall,',
#   '0.170000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.170000s',
#   'CPU',
#   '(97.6%)'],
#  ['Pearce',
#   '0.171979s',
#   'wall,',
#   '0.170000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.170000s',
#   'CPU',
#   '(98.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.101010_961.xml', '60K'],
#  ['Tarjan',
#   '0.177792s',
#   'wall,',
#   '0.180000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.180000s',
#   'CPU',
#   '(101.2%)'],
#  ['Nuutila',
#   '0.166048s',
#   'wall,',
#   '0.160000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.160000s',
#   'CPU',
#   '(96.4%)'],
#  ['Pearce',
#   '0.170071s',
#   'wall,',
#   '0.170000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.170000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.111111_1050.xml', '64K'],
#  ['Tarjan',
#   '0.183988s',
#   'wall,',
#   '0.180000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.180000s',
#   'CPU',
#   '(97.8%)'],
#  ['Nuutila',
#   '0.208882s',
#   'wall,',
#   '0.210000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.210000s',
#   'CPU',
#   '(100.5%)'],
#  ['Pearce',
#   '0.210045s',
#   'wall,',
#   '0.210000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.210000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.121212_1141.xml', '72K'],
#  ['Tarjan',
#   '0.228526s',
#   'wall,',
#   '0.220000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.220000s',
#   'CPU',
#   '(96.3%)'],
#  ['Nuutila',
#   '0.225226s',
#   'wall,',
#   '0.230000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.230000s',
#   'CPU',
#   '(102.1%)'],
#  ['Pearce',
#   '0.225823s',
#   'wall,',
#   '0.220000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.220000s',
#   'CPU',
#   '(97.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.131313_1235.xml', '76K'],
#  ['Tarjan',
#   '0.239248s',
#   'wall,',
#   '0.230000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.230000s',
#   'CPU',
#   '(96.1%)'],
#  ['Nuutila',
#   '0.208524s',
#   'wall,',
#   '0.210000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.210000s',
#   'CPU',
#   '(100.7%)'],
#  ['Pearce',
#   '0.213661s',
#   'wall,',
#   '0.210000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.210000s',
#   'CPU',
#   '(98.3%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.141414_1323.xml', '80K'],
#  ['Tarjan',
#   '0.231875s',
#   'wall,',
#   '0.230000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.230000s',
#   'CPU',
#   '(99.2%)'],
#  ['Nuutila',
#   '0.255029s',
#   'wall,',
#   '0.260000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.260000s',
#   'CPU',
#   '(101.9%)'],
#  ['Pearce',
#   '0.252699s',
#   'wall,',
#   '0.250000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.250000s',
#   'CPU',
#   '(98.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.151515_1409.xml', '88K'],
#  ['Tarjan',
#   '0.267546s',
#   'wall,',
#   '0.260000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.260000s',
#   'CPU',
#   '(97.2%)'],
#  ['Nuutila',
#   '0.273181s',
#   'wall,',
#   '0.280000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.280000s',
#   'CPU',
#   '(102.5%)'],
#  ['Pearce',
#   '0.259050s',
#   'wall,',
#   '0.250000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.250000s',
#   'CPU',
#   '(96.5%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.161616_1493.xml', '92K'],
#  ['Tarjan',
#   '0.250379s',
#   'wall,',
#   '0.240000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.250000s',
#   'CPU',
#   '(99.8%)'],
#  ['Nuutila',
#   '0.255450s',
#   'wall,',
#   '0.250000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.250000s',
#   'CPU',
#   '(97.9%)'],
#  ['Pearce',
#   '0.276821s',
#   'wall,',
#   '0.280000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.280000s',
#   'CPU',
#   '(101.1%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.171717_1578.xml', '96K'],
#  ['Tarjan',
#   '0.301697s',
#   'wall,',
#   '0.310000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.310000s',
#   'CPU',
#   '(102.8%)'],
#  ['Nuutila',
#   '0.305864s',
#   'wall,',
#   '0.300000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.300000s',
#   'CPU',
#   '(98.1%)'],
#  ['Pearce',
#   '0.302214s',
#   'wall,',
#   '0.300000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.300000s',
#   'CPU',
#   '(99.3%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.181818_1661.xml', '100K'],
#  ['Tarjan',
#   '0.287929s',
#   'wall,',
#   '0.280000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.280000s',
#   'CPU',
#   '(97.2%)'],
#  ['Nuutila',
#   '0.293211s',
#   'wall,',
#   '0.290000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.290000s',
#   'CPU',
#   '(98.9%)'],
#  ['Pearce',
#   '0.281650s',
#   'wall,',
#   '0.280000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.280000s',
#   'CPU',
#   '(99.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.191919_1748.xml', '108K'],
#  ['Tarjan',
#   '0.334927s',
#   'wall,',
#   '0.330000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.330000s',
#   'CPU',
#   '(98.5%)'],
#  ['Nuutila',
#   '0.333709s',
#   'wall,',
#   '0.330000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.330000s',
#   'CPU',
#   '(98.9%)'],
#  ['Pearce',
#   '0.338277s',
#   'wall,',
#   '0.340000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.340000s',
#   'CPU',
#   '(100.5%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.202020_1832.xml', '112K'],
#  ['Tarjan',
#   '0.311248s',
#   'wall,',
#   '0.300000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.310000s',
#   'CPU',
#   '(99.6%)'],
#  ['Nuutila',
#   '0.309038s',
#   'wall,',
#   '0.310000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.310000s',
#   'CPU',
#   '(100.3%)'],
#  ['Pearce',
#   '0.325693s',
#   'wall,',
#   '0.330000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.330000s',
#   'CPU',
#   '(101.3%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.212121_1918.xml', '116K'],
#  ['Tarjan',
#   '0.372682s',
#   'wall,',
#   '0.370000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.370000s',
#   'CPU',
#   '(99.3%)'],
#  ['Nuutila',
#   '0.375040s',
#   'wall,',
#   '0.370000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.370000s',
#   'CPU',
#   '(98.7%)'],
#  ['Pearce',
#   '0.362538s',
#   'wall,',
#   '0.360000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.360000s',
#   'CPU',
#   '(99.3%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.222222_1993.xml', '120K'],
#  ['Tarjan',
#   '0.385085s',
#   'wall,',
#   '0.380000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.380000s',
#   'CPU',
#   '(98.7%)'],
#  ['Nuutila',
#   '0.386790s',
#   'wall,',
#   '0.380000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.380000s',
#   'CPU',
#   '(98.2%)'],
#  ['Pearce',
#   '0.376618s',
#   'wall,',
#   '0.370000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.370000s',
#   'CPU',
#   '(98.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.232323_2074.xml', '124K'],
#  ['Tarjan',
#   '0.399257s',
#   'wall,',
#   '0.390000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.390000s',
#   'CPU',
#   '(97.7%)'],
#  ['Nuutila',
#   '0.393424s',
#   'wall,',
#   '0.390000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.390000s',
#   'CPU',
#   '(99.1%)'],
#  ['Pearce',
#   '0.355400s',
#   'wall,',
#   '0.340000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.340000s',
#   'CPU',
#   '(95.7%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.242424_2159.xml', '132K'],
#  ['Tarjan',
#   '0.383450s',
#   'wall,',
#   '0.370000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.370000s',
#   'CPU',
#   '(96.5%)'],
#  ['Nuutila',
#   '0.413888s',
#   'wall,',
#   '0.410000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.410000s',
#   'CPU',
#   '(99.1%)'],
#  ['Pearce',
#   '0.408213s',
#   'wall,',
#   '0.400000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.410000s',
#   'CPU',
#   '(100.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.252525_2244.xml', '136K'],
#  ['Tarjan',
#   '0.417531s',
#   'wall,',
#   '0.410000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.410000s',
#   'CPU',
#   '(98.2%)'],
#  ['Nuutila',
#   '0.388463s',
#   'wall,',
#   '0.380000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.380000s',
#   'CPU',
#   '(97.8%)'],
#  ['Pearce',
#   '0.422290s',
#   'wall,',
#   '0.420000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.420000s',
#   'CPU',
#   '(99.5%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.262626_2326.xml', '140K'],
#  ['Tarjan',
#   '0.435306s',
#   'wall,',
#   '0.440000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.440000s',
#   'CPU',
#   '(101.1%)'],
#  ['Nuutila',
#   '0.426059s',
#   'wall,',
#   '0.430000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.430000s',
#   'CPU',
#   '(100.9%)'],
#  ['Pearce',
#   '0.382168s',
#   'wall,',
#   '0.380000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.380000s',
#   'CPU',
#   '(99.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.272727_2408.xml', '144K'],
#  ['Tarjan',
#   '0.421230s',
#   'wall,',
#   '0.420000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.420000s',
#   'CPU',
#   '(99.7%)'],
#  ['Nuutila',
#   '0.443886s',
#   'wall,',
#   '0.450000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.450000s',
#   'CPU',
#   '(101.4%)'],
#  ['Pearce',
#   '0.450035s',
#   'wall,',
#   '0.450000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.450000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.282828_2479.xml', '148K'],
#  ['Tarjan',
#   '0.443300s',
#   'wall,',
#   '0.430000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.440000s',
#   'CPU',
#   '(99.3%)'],
#  ['Nuutila',
#   '0.418986s',
#   'wall,',
#   '0.420000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.420000s',
#   'CPU',
#   '(100.2%)'],
#  ['Pearce',
#   '0.433803s',
#   'wall,',
#   '0.440000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.440000s',
#   'CPU',
#   '(101.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.292929_2555.xml', '152K'],
#  ['Tarjan',
#   '0.471579s',
#   'wall,',
#   '0.480000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.480000s',
#   'CPU',
#   '(101.8%)'],
#  ['Nuutila',
#   '0.465287s',
#   'wall,',
#   '0.460000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.460000s',
#   'CPU',
#   '(98.9%)'],
#  ['Pearce',
#   '0.414843s',
#   'wall,',
#   '0.420000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.420000s',
#   'CPU',
#   '(101.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.303030_2629.xml', '156K'],
#  ['Tarjan',
#   '0.450240s',
#   'wall,',
#   '0.450000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.450000s',
#   'CPU',
#   '(99.9%)'],
#  ['Nuutila',
#   '0.485506s',
#   'wall,',
#   '0.480000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.480000s',
#   'CPU',
#   '(98.9%)'],
#  ['Pearce',
#   '0.485112s',
#   'wall,',
#   '0.490000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.490000s',
#   'CPU',
#   '(101.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.313131_2699.xml', '164K'],
#  ['Tarjan',
#   '0.456890s',
#   'wall,',
#   '0.450000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.450000s',
#   'CPU',
#   '(98.5%)'],
#  ['Nuutila',
#   '0.472413s',
#   'wall,',
#   '0.460000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.460000s',
#   'CPU',
#   '(97.4%)'],
#  ['Pearce',
#   '0.501108s',
#   'wall,',
#   '0.500000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.500000s',
#   'CPU',
#   '(99.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.323232_2774.xml', '168K'],
#  ['Tarjan',
#   '0.506759s',
#   'wall,',
#   '0.510000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.510000s',
#   'CPU',
#   '(100.6%)'],
#  ['Nuutila',
#   '0.458553s',
#   'wall,',
#   '0.450000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.450000s',
#   'CPU',
#   '(98.1%)'],
#  ['Pearce',
#   '0.471837s',
#   'wall,',
#   '0.480000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.480000s',
#   'CPU',
#   '(101.7%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.333333_2856.xml', '172K'],
#  ['Tarjan',
#   '0.524392s',
#   'wall,',
#   '0.520000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.520000s',
#   'CPU',
#   '(99.2%)'],
#  ['Nuutila',
#   '0.504327s',
#   'wall,',
#   '0.500000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.500000s',
#   'CPU',
#   '(99.1%)'],
#  ['Pearce',
#   '0.459628s',
#   'wall,',
#   '0.460000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.460000s',
#   'CPU',
#   '(100.1%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.343434_2927.xml', '176K'],
#  ['Tarjan',
#   '0.529015s',
#   'wall,',
#   '0.520000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.520000s',
#   'CPU',
#   '(98.3%)'],
#  ['Nuutila',
#   '0.541481s',
#   'wall,',
#   '0.540000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.540000s',
#   'CPU',
#   '(99.7%)'],
#  ['Pearce',
#   '0.509649s',
#   'wall,',
#   '0.510000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.510000s',
#   'CPU',
#   '(100.1%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.353535_2999.xml', '180K'],
#  ['Tarjan',
#   '0.532082s',
#   'wall,',
#   '0.510000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.520000s',
#   'CPU',
#   '(97.7%)'],
#  ['Nuutila',
#   '0.568468s',
#   'wall,',
#   '0.560000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.560000s',
#   'CPU',
#   '(98.5%)'],
#  ['Pearce',
#   '0.559056s',
#   'wall,',
#   '0.560000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.560000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.363636_3071.xml', '184K'],
#  ['Tarjan',
#   '0.497132s',
#   'wall,',
#   '0.490000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.500000s',
#   'CPU',
#   '(100.6%)'],
#  ['Nuutila',
#   '0.536981s',
#   'wall,',
#   '0.540000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.540000s',
#   'CPU',
#   '(100.6%)'],
#  ['Pearce',
#   '0.557946s',
#   'wall,',
#   '0.560000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.560000s',
#   'CPU',
#   '(100.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.373737_3139.xml', '188K'],
#  ['Tarjan',
#   '0.570301s',
#   'wall,',
#   '0.560000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.560000s',
#   'CPU',
#   '(98.2%)'],
#  ['Nuutila',
#   '0.544647s',
#   'wall,',
#   '0.530000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.530000s',
#   'CPU',
#   '(97.3%)'],
#  ['Pearce',
#   '0.587262s',
#   'wall,',
#   '0.580000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.580000s',
#   'CPU',
#   '(98.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.383838_3207.xml', '192K'],
#  ['Tarjan',
#   '0.593490s',
#   'wall,',
#   '0.580000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.580000s',
#   'CPU',
#   '(97.7%)'],
#  ['Nuutila',
#   '0.556997s',
#   'wall,',
#   '0.560000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.560000s',
#   'CPU',
#   '(100.5%)'],
#  ['Pearce',
#   '0.588397s',
#   'wall,',
#   '0.580000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.580000s',
#   'CPU',
#   '(98.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.393939_3268.xml', '196K'],
#  ['Tarjan',
#   '0.593056s',
#   'wall,',
#   '0.590000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.590000s',
#   'CPU',
#   '(99.5%)'],
#  ['Nuutila',
#   '0.565739s',
#   'wall,',
#   '0.560000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.560000s',
#   'CPU',
#   '(99.0%)'],
#  ['Pearce',
#   '0.585635s',
#   'wall,',
#   '0.580000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.580000s',
#   'CPU',
#   '(99.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.404040_3327.xml', '200K'],
#  ['Tarjan',
#   '0.621660s',
#   'wall,',
#   '0.620000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.620000s',
#   'CPU',
#   '(99.7%)'],
#  ['Nuutila',
#   '0.589703s',
#   'wall,',
#   '0.580000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.580000s',
#   'CPU',
#   '(98.4%)'],
#  ['Pearce',
#   '0.605545s',
#   'wall,',
#   '0.610000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.610000s',
#   'CPU',
#   '(100.7%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.414141_3399.xml', '204K'],
#  ['Tarjan',
#   '0.637549s',
#   'wall,',
#   '0.630000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.630000s',
#   'CPU',
#   '(98.8%)'],
#  ['Nuutila',
#   '0.621695s',
#   'wall,',
#   '0.630000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.630000s',
#   'CPU',
#   '(101.3%)'],
#  ['Pearce',
#   '0.596329s',
#   'wall,',
#   '0.590000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.590000s',
#   'CPU',
#   '(98.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.424242_3463.xml', '208K'],
#  ['Tarjan',
#   '0.651412s',
#   'wall,',
#   '0.650000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.660000s',
#   'CPU',
#   '(101.3%)'],
#  ['Nuutila',
#   '0.607475s',
#   'wall,',
#   '0.600000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.600000s',
#   'CPU',
#   '(98.8%)'],
#  ['Pearce',
#   '0.622145s',
#   'wall,',
#   '0.630000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.630000s',
#   'CPU',
#   '(101.3%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.434343_3533.xml', '212K'],
#  ['Tarjan',
#   '0.660430s',
#   'wall,',
#   '0.660000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.660000s',
#   'CPU',
#   '(99.9%)'],
#  ['Nuutila',
#   '0.625563s',
#   'wall,',
#   '0.620000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.620000s',
#   'CPU',
#   '(99.1%)'],
#  ['Pearce',
#   '0.630271s',
#   'wall,',
#   '0.630000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.630000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.444444_3603.xml', '216K'],
#  ['Tarjan',
#   '0.675658s',
#   'wall,',
#   '0.670000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.670000s',
#   'CPU',
#   '(99.2%)'],
#  ['Nuutila',
#   '0.632567s',
#   'wall,',
#   '0.640000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.640000s',
#   'CPU',
#   '(101.2%)'],
#  ['Pearce',
#   '0.627813s',
#   'wall,',
#   '0.620000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.630000s',
#   'CPU',
#   '(100.3%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.454545_3665.xml', '220K'],
#  ['Tarjan',
#   '0.693587s',
#   'wall,',
#   '0.670000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.670000s',
#   'CPU',
#   '(96.6%)'],
#  ['Nuutila',
#   '0.666636s',
#   'wall,',
#   '0.650000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.660000s',
#   'CPU',
#   '(99.0%)'],
#  ['Pearce',
#   '0.680417s',
#   'wall,',
#   '0.660000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.660000s',
#   'CPU',
#   '(97.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.464646_3730.xml', '224K'],
#  ['Tarjan',
#   '0.699105s',
#   'wall,',
#   '0.700000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.700000s',
#   'CPU',
#   '(100.1%)'],
#  ['Nuutila',
#   '0.653192s',
#   'wall,',
#   '0.660000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.660000s',
#   'CPU',
#   '(101.0%)'],
#  ['Pearce',
#   '0.663020s',
#   'wall,',
#   '0.660000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.660000s',
#   'CPU',
#   '(99.5%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.474747_3796.xml', '228K'],
#  ['Tarjan',
#   '0.700021s',
#   'wall,',
#   '0.690000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.690000s',
#   'CPU',
#   '(98.6%)'],
#  ['Nuutila',
#   '0.642932s',
#   'wall,',
#   '0.640000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.640000s',
#   'CPU',
#   '(99.5%)'],
#  ['Pearce',
#   '0.697788s',
#   'wall,',
#   '0.690000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.690000s',
#   'CPU',
#   '(98.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.484848_3861.xml', '228K'],
#  ['Tarjan',
#   '0.693393s',
#   'wall,',
#   '0.680000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.690000s',
#   'CPU',
#   '(99.5%)'],
#  ['Nuutila',
#   '0.654434s',
#   'wall,',
#   '0.650000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.650000s',
#   'CPU',
#   '(99.3%)'],
#  ['Pearce',
#   '0.718663s',
#   'wall,',
#   '0.720000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.720000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.494949_3920.xml', '232K'],
#  ['Tarjan',
#   '0.681941s',
#   'wall,',
#   '0.660000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.670000s',
#   'CPU',
#   '(98.2%)'],
#  ['Nuutila',
#   '0.704649s',
#   'wall,',
#   '0.690000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.690000s',
#   'CPU',
#   '(97.9%)'],
#  ['Pearce',
#   '0.727422s',
#   'wall,',
#   '0.730000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.730000s',
#   'CPU',
#   '(100.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.505051_3977.xml', '236K'],
#  ['Tarjan',
#   '0.687445s',
#   'wall,',
#   '0.680000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.690000s',
#   'CPU',
#   '(100.4%)'],
#  ['Nuutila',
#   '0.714682s',
#   'wall,',
#   '0.710000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.710000s',
#   'CPU',
#   '(99.3%)'],
#  ['Pearce',
#   '0.719420s',
#   'wall,',
#   '0.720000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.720000s',
#   'CPU',
#   '(100.1%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.515152_4042.xml', '240K'],
#  ['Tarjan',
#   '0.701437s',
#   'wall,',
#   '0.700000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.700000s',
#   'CPU',
#   '(99.8%)'],
#  ['Nuutila',
#   '0.741564s',
#   'wall,',
#   '0.740000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.750000s',
#   'CPU',
#   '(101.1%)'],
#  ['Pearce',
#   '0.702621s',
#   'wall,',
#   '0.700000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.700000s',
#   'CPU',
#   '(99.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.525253_4090.xml', '244K'],
#  ['Tarjan',
#   '0.739057s',
#   'wall,',
#   '0.730000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.740000s',
#   'CPU',
#   '(100.1%)'],
#  ['Nuutila',
#   '0.750816s',
#   'wall,',
#   '0.750000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.750000s',
#   'CPU',
#   '(99.9%)'],
#  ['Pearce',
#   '0.691444s',
#   'wall,',
#   '0.700000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.700000s',
#   'CPU',
#   '(101.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.535354_4139.xml', '248K'],
#  ['Tarjan',
#   '0.752793s',
#   'wall,',
#   '0.740000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.750000s',
#   'CPU',
#   '(99.6%)'],
#  ['Nuutila',
#   '0.744129s',
#   'wall,',
#   '0.740000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.740000s',
#   'CPU',
#   '(99.4%)'],
#  ['Pearce',
#   '0.687593s',
#   'wall,',
#   '0.690000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.690000s',
#   'CPU',
#   '(100.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.545455_4203.xml', '248K'],
#  ['Tarjan',
#   '0.777150s',
#   'wall,',
#   '0.780000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.780000s',
#   'CPU',
#   '(100.4%)'],
#  ['Nuutila',
#   '0.717506s',
#   'wall,',
#   '0.720000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.720000s',
#   'CPU',
#   '(100.3%)'],
#  ['Pearce',
#   '0.730842s',
#   'wall,',
#   '0.730000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.730000s',
#   'CPU',
#   '(99.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.555556_4260.xml', '252K'],
#  ['Tarjan',
#   '0.770229s',
#   'wall,',
#   '0.760000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.760000s',
#   'CPU',
#   '(98.7%)'],
#  ['Nuutila',
#   '0.696054s',
#   'wall,',
#   '0.700000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.700000s',
#   'CPU',
#   '(100.6%)'],
#  ['Pearce',
#   '0.774701s',
#   'wall,',
#   '0.770000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.770000s',
#   'CPU',
#   '(99.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.565657_4329.xml', '256K'],
#  ['Tarjan',
#   '0.749052s',
#   'wall,',
#   '0.750000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.750000s',
#   'CPU',
#   '(100.1%)'],
#  ['Nuutila',
#   '0.744878s',
#   'wall,',
#   '0.740000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.740000s',
#   'CPU',
#   '(99.3%)'],
#  ['Pearce',
#   '0.788330s',
#   'wall,',
#   '0.790000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.790000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.575758_4379.xml', '260K'],
#  ['Tarjan',
#   '0.711010s',
#   'wall,',
#   '0.700000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.710000s',
#   'CPU',
#   '(99.9%)'],
#  ['Nuutila',
#   '0.799186s',
#   'wall,',
#   '0.800000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.800000s',
#   'CPU',
#   '(100.1%)'],
#  ['Pearce',
#   '0.799677s',
#   'wall,',
#   '0.790000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.790000s',
#   'CPU',
#   '(98.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.585859_4434.xml', '264K'],
#  ['Tarjan',
#   '0.768764s',
#   'wall,',
#   '0.760000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.770000s',
#   'CPU',
#   '(100.2%)'],
#  ['Nuutila',
#   '0.803475s',
#   'wall,',
#   '0.810000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.810000s',
#   'CPU',
#   '(100.8%)'],
#  ['Pearce',
#   '0.712257s',
#   'wall,',
#   '0.710000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.710000s',
#   'CPU',
#   '(99.7%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.595960_4496.xml', '268K'],
#  ['Tarjan',
#   '0.819019s',
#   'wall,',
#   '0.820000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.820000s',
#   'CPU',
#   '(100.1%)'],
#  ['Nuutila',
#   '0.750926s',
#   'wall,',
#   '0.750000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.750000s',
#   'CPU',
#   '(99.9%)'],
#  ['Pearce',
#   '0.781410s',
#   'wall,',
#   '0.780000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.780000s',
#   'CPU',
#   '(99.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.606061_4547.xml', '268K'],
#  ['Tarjan',
#   '0.802901s',
#   'wall,',
#   '0.800000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.800000s',
#   'CPU',
#   '(99.6%)'],
#  ['Nuutila',
#   '0.744791s',
#   'wall,',
#   '0.750000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.750000s',
#   'CPU',
#   '(100.7%)'],
#  ['Pearce',
#   '0.830294s',
#   'wall,',
#   '0.830000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.830000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.616162_4604.xml', '272K'],
#  ['Tarjan',
#   '0.752628s',
#   'wall,',
#   '0.750000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.750000s',
#   'CPU',
#   '(99.7%)'],
#  ['Nuutila',
#   '0.823626s',
#   'wall,',
#   '0.820000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.820000s',
#   'CPU',
#   '(99.6%)'],
#  ['Pearce',
#   '0.805707s',
#   'wall,',
#   '0.810000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.810000s',
#   'CPU',
#   '(100.5%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.626263_4654.xml', '276K'],
#  ['Tarjan',
#   '0.795660s',
#   'wall,',
#   '0.790000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.790000s',
#   'CPU',
#   '(99.3%)'],
#  ['Nuutila',
#   '0.839851s',
#   'wall,',
#   '0.840000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.840000s',
#   'CPU',
#   '(100.0%)'],
#  ['Pearce',
#   '0.793742s',
#   'wall,',
#   '0.800000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.800000s',
#   'CPU',
#   '(100.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.636364_4705.xml', '280K'],
#  ['Tarjan',
#   '0.844179s',
#   'wall,',
#   '0.840000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.850000s',
#   'CPU',
#   '(100.7%)'],
#  ['Nuutila',
#   '0.786377s',
#   'wall,',
#   '0.780000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.780000s',
#   'CPU',
#   '(99.2%)'],
#  ['Pearce',
#   '0.829756s',
#   'wall,',
#   '0.830000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.830000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.646465_4772.xml', '284K'],
#  ['Tarjan',
#   '0.830952s',
#   'wall,',
#   '0.820000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.830000s',
#   'CPU',
#   '(99.9%)'],
#  ['Nuutila',
#   '0.810802s',
#   'wall,',
#   '0.810000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.810000s',
#   'CPU',
#   '(99.9%)'],
#  ['Pearce',
#   '0.850028s',
#   'wall,',
#   '0.850000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.850000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.656566_4820.xml', '284K'],
#  ['Tarjan',
#   '0.783915s',
#   'wall,',
#   '0.770000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.780000s',
#   'CPU',
#   '(99.5%)'],
#  ['Nuutila',
#   '0.843952s',
#   'wall,',
#   '0.850000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.850000s',
#   'CPU',
#   '(100.7%)'],
#  ['Pearce',
#   '0.781075s',
#   'wall,',
#   '0.780000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.780000s',
#   'CPU',
#   '(99.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.666667_4876.xml', '288K'],
#  ['Tarjan',
#   '0.866030s',
#   'wall,',
#   '0.860000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.860000s',
#   'CPU',
#   '(99.3%)'],
#  ['Nuutila',
#   '0.818490s',
#   'wall,',
#   '0.820000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.820000s',
#   'CPU',
#   '(100.2%)'],
#  ['Pearce',
#   '0.808227s',
#   'wall,',
#   '0.810000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.810000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.676768_4930.xml', '292K'],
#  ['Tarjan',
#   '0.861292s',
#   'wall,',
#   '0.850000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.850000s',
#   'CPU',
#   '(98.7%)'],
#  ['Nuutila',
#   '0.807993s',
#   'wall,',
#   '0.810000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.810000s',
#   'CPU',
#   '(100.2%)'],
#  ['Pearce',
#   '0.870892s',
#   'wall,',
#   '0.870000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.870000s',
#   'CPU',
#   '(99.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.686869_4976.xml', '296K'],
#  ['Tarjan',
#   '0.842232s',
#   'wall,',
#   '0.830000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.830000s',
#   'CPU',
#   '(98.5%)'],
#  ['Nuutila',
#   '0.894069s',
#   'wall,',
#   '0.890000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.890000s',
#   'CPU',
#   '(99.5%)'],
#  ['Pearce',
#   '0.820108s',
#   'wall,',
#   '0.820000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.820000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.696970_5023.xml', '296K'],
#  ['Tarjan',
#   '0.879306s',
#   'wall,',
#   '0.880000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.880000s',
#   'CPU',
#   '(100.1%)'],
#  ['Nuutila',
#   '0.846352s',
#   'wall,',
#   '0.830000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.830000s',
#   'CPU',
#   '(98.1%)'],
#  ['Pearce',
#   '0.862549s',
#   'wall,',
#   '0.860000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.860000s',
#   'CPU',
#   '(99.7%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.707071_5082.xml', '300K'],
#  ['Tarjan',
#   '0.858487s',
#   'wall,',
#   '0.850000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.850000s',
#   'CPU',
#   '(99.0%)'],
#  ['Nuutila',
#   '0.840005s',
#   'wall,',
#   '0.840000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.840000s',
#   'CPU',
#   '(100.0%)'],
#  ['Pearce',
#   '0.905813s',
#   'wall,',
#   '0.910000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.910000s',
#   'CPU',
#   '(100.5%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.717172_5135.xml', '304K'],
#  ['Tarjan',
#   '0.849968s',
#   'wall,',
#   '0.820000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.830000s',
#   'CPU',
#   '(97.7%)'],
#  ['Nuutila',
#   '0.926446s',
#   'wall,',
#   '0.920000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.920000s',
#   'CPU',
#   '(99.3%)'],
#  ['Pearce',
#   '0.869326s',
#   'wall,',
#   '0.850000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.850000s',
#   'CPU',
#   '(97.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.727273_5186.xml', '308K'],
#  ['Tarjan',
#   '0.933097s',
#   'wall,',
#   '0.930000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.930000s',
#   'CPU',
#   '(99.7%)'],
#  ['Nuutila',
#   '0.841130s',
#   'wall,',
#   '0.820000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.820000s',
#   'CPU',
#   '(97.5%)'],
#  ['Pearce',
#   '0.918908s',
#   'wall,',
#   '0.910000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.910000s',
#   'CPU',
#   '(99.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.737374_5234.xml', '312K'],
#  ['Tarjan',
#   '0.853371s',
#   'wall,',
#   '0.860000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.860000s',
#   'CPU',
#   '(100.8%)'],
#  ['Nuutila',
#   '0.904335s',
#   'wall,',
#   '0.900000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.900000s',
#   'CPU',
#   '(99.5%)'],
#  ['Pearce',
#   '0.868454s',
#   'wall,',
#   '0.870000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.870000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.747475_5277.xml', '312K'],
#  ['Tarjan',
#   '0.898358s',
#   'wall,',
#   '0.900000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.910000s',
#   'CPU',
#   '(101.3%)'],
#  ['Nuutila',
#   '0.887400s',
#   'wall,',
#   '0.880000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.880000s',
#   'CPU',
#   '(99.2%)'],
#  ['Pearce',
#   '0.880267s',
#   'wall,',
#   '0.880000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.880000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.757576_5324.xml', '316K'],
#  ['Tarjan',
#   '0.922355s',
#   'wall,',
#   '0.920000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.920000s',
#   'CPU',
#   '(99.7%)'],
#  ['Nuutila',
#   '0.921025s',
#   'wall,',
#   '0.920000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.920000s',
#   'CPU',
#   '(99.9%)'],
#  ['Pearce',
#   '0.948129s',
#   'wall,',
#   '0.950000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.950000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.767677_5364.xml', '316K'],
#  ['Tarjan',
#   '0.913556s',
#   'wall,',
#   '0.900000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.900000s',
#   'CPU',
#   '(98.5%)'],
#  ['Nuutila',
#   '0.913344s',
#   'wall,',
#   '0.910000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.910000s',
#   'CPU',
#   '(99.6%)'],
#  ['Pearce',
#   '0.913771s',
#   'wall,',
#   '0.910000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.910000s',
#   'CPU',
#   '(99.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.777778_5405.xml', '320K'],
#  ['Tarjan',
#   '0.936744s',
#   'wall,',
#   '0.920000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.930000s',
#   'CPU',
#   '(99.3%)'],
#  ['Nuutila',
#   '0.896880s',
#   'wall,',
#   '0.900000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.900000s',
#   'CPU',
#   '(100.3%)'],
#  ['Pearce',
#   '0.946009s',
#   'wall,',
#   '0.940000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.940000s',
#   'CPU',
#   '(99.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.787879_5460.xml', '324K'],
#  ['Tarjan',
#   '0.878311s',
#   'wall,',
#   '0.870000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.880000s',
#   'CPU',
#   '(100.2%)'],
#  ['Nuutila',
#   '0.942401s',
#   'wall,',
#   '0.940000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.940000s',
#   'CPU',
#   '(99.7%)'],
#  ['Pearce',
#   '0.881310s',
#   'wall,',
#   '0.880000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.880000s',
#   'CPU',
#   '(99.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.797980_5509.xml', '328K'],
#  ['Tarjan',
#   '0.955887s',
#   'wall,',
#   '0.950000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.960000s',
#   'CPU',
#   '(100.4%)'],
#  ['Nuutila',
#   '0.878539s',
#   'wall,',
#   '0.880000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.880000s',
#   'CPU',
#   '(100.2%)'],
#  ['Pearce',
#   '0.953944s',
#   'wall,',
#   '0.950000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.950000s',
#   'CPU',
#   '(99.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.808081_5555.xml', '328K'],
#  ['Tarjan',
#   '0.879030s',
#   'wall,',
#   '0.880000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.880000s',
#   'CPU',
#   '(100.1%)'],
#  ['Nuutila',
#   '0.962391s',
#   'wall,',
#   '0.960000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.960000s',
#   'CPU',
#   '(99.8%)'],
#  ['Pearce',
#   '0.888657s',
#   'wall,',
#   '0.890000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.890000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.818182_5598.xml', '332K'],
#  ['Tarjan',
#   '0.971256s',
#   'wall,',
#   '0.970000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.970000s',
#   'CPU',
#   '(99.9%)'],
#  ['Nuutila',
#   '0.932489s',
#   'wall,',
#   '0.930000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.930000s',
#   'CPU',
#   '(99.7%)'],
#  ['Pearce',
#   '0.968971s',
#   'wall,',
#   '0.970000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.970000s',
#   'CPU',
#   '(100.1%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.828283_5639.xml', '332K'],
#  ['Tarjan',
#   '0.898301s',
#   'wall,',
#   '0.890000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '0.900000s',
#   'CPU',
#   '(100.2%)'],
#  ['Nuutila',
#   '0.966863s',
#   'wall,',
#   '0.970000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.970000s',
#   'CPU',
#   '(100.3%)'],
#  ['Pearce',
#   '0.912565s',
#   'wall,',
#   '0.910000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.910000s',
#   'CPU',
#   '(99.7%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.838384_5685.xml', '336K'],
#  ['Tarjan',
#   '0.977244s',
#   'wall,',
#   '0.970000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.970000s',
#   'CPU',
#   '(99.3%)'],
#  ['Nuutila',
#   '0.913614s',
#   'wall,',
#   '0.920000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.920000s',
#   'CPU',
#   '(100.7%)'],
#  ['Pearce',
#   '0.973647s',
#   'wall,',
#   '0.970000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.970000s',
#   'CPU',
#   '(99.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.848485_5725.xml', '340K'],
#  ['Tarjan',
#   '0.923277s',
#   'wall,',
#   '0.920000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.920000s',
#   'CPU',
#   '(99.6%)'],
#  ['Nuutila',
#   '0.995671s',
#   'wall,',
#   '0.980000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.980000s',
#   'CPU',
#   '(98.4%)'],
#  ['Pearce',
#   '0.947509s',
#   'wall,',
#   '0.930000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.930000s',
#   'CPU',
#   '(98.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.858586_5768.xml', '340K'],
#  ['Tarjan',
#   '1.005255s',
#   'wall,',
#   '0.990000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.000000s',
#   'CPU',
#   '(99.5%)'],
#  ['Nuutila',
#   '0.969254s',
#   'wall,',
#   '0.970000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.970000s',
#   'CPU',
#   '(100.1%)'],
#  ['Pearce',
#   '1.003658s',
#   'wall,',
#   '1.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.000000s',
#   'CPU',
#   '(99.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.868687_5810.xml', '344K'],
#  ['Tarjan',
#   '0.951728s',
#   'wall,',
#   '0.940000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.940000s',
#   'CPU',
#   '(98.8%)'],
#  ['Nuutila',
#   '1.010546s',
#   'wall,',
#   '1.010000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.010000s',
#   'CPU',
#   '(99.9%)'],
#  ['Pearce',
#   '0.940184s',
#   'wall,',
#   '0.940000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.940000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.878788_5855.xml', '348K'],
#  ['Tarjan',
#   '1.037320s',
#   'wall,',
#   '1.010000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.020000s',
#   'CPU',
#   '(98.3%)'],
#  ['Nuutila',
#   '1.005978s',
#   'wall,',
#   '0.990000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.990000s',
#   'CPU',
#   '(98.4%)'],
#  ['Pearce',
#   '1.036076s',
#   'wall,',
#   '1.020000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.020000s',
#   'CPU',
#   '(98.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.888889_5891.xml', '348K'],
#  ['Tarjan',
#   '1.002663s',
#   'wall,',
#   '1.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.000000s',
#   'CPU',
#   '(99.7%)'],
#  ['Nuutila',
#   '1.017538s',
#   'wall,',
#   '1.010000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.010000s',
#   'CPU',
#   '(99.3%)'],
#  ['Pearce',
#   '1.001565s',
#   'wall,',
#   '1.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.000000s',
#   'CPU',
#   '(99.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.898990_5926.xml', '352K'],
#  ['Tarjan',
#   '1.007943s',
#   'wall,',
#   '1.000000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.010000s',
#   'CPU',
#   '(100.2%)'],
#  ['Nuutila',
#   '1.042550s',
#   'wall,',
#   '1.040000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.040000s',
#   'CPU',
#   '(99.8%)'],
#  ['Pearce',
#   '0.995542s',
#   'wall,',
#   '0.990000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.990000s',
#   'CPU',
#   '(99.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.909091_5971.xml', '352K'],
#  ['Tarjan',
#   '1.041055s',
#   'wall,',
#   '1.030000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.040000s',
#   'CPU',
#   '(99.9%)'],
#  ['Nuutila',
#   '0.955095s',
#   'wall,',
#   '0.950000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '0.950000s',
#   'CPU',
#   '(99.5%)'],
#  ['Pearce',
#   '1.052657s',
#   'wall,',
#   '1.050000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.050000s',
#   'CPU',
#   '(99.7%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.919192_6016.xml', '356K'],
#  ['Tarjan',
#   '1.019717s',
#   'wall,',
#   '1.020000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.020000s',
#   'CPU',
#   '(100.0%)'],
#  ['Nuutila',
#   '1.053469s',
#   'wall,',
#   '1.050000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.050000s',
#   'CPU',
#   '(99.7%)'],
#  ['Pearce',
#   '1.037857s',
#   'wall,',
#   '1.040000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.040000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.929293_6058.xml', '360K'],
#  ['Tarjan',
#   '1.043526s',
#   'wall,',
#   '1.040000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.040000s',
#   'CPU',
#   '(99.7%)'],
#  ['Nuutila',
#   '1.035054s',
#   'wall,',
#   '1.030000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.030000s',
#   'CPU',
#   '(99.5%)'],
#  ['Pearce',
#   '1.036655s',
#   'wall,',
#   '1.040000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.040000s',
#   'CPU',
#   '(100.3%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.939394_6097.xml', '360K'],
#  ['Tarjan',
#   '1.071976s',
#   'wall,',
#   '1.060000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.070000s',
#   'CPU',
#   '(99.8%)'],
#  ['Nuutila',
#   '1.044151s',
#   'wall,',
#   '1.040000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.040000s',
#   'CPU',
#   '(99.6%)'],
#  ['Pearce',
#   '1.069897s',
#   'wall,',
#   '1.070000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.070000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['100_0.949495_6133.xml', '364K'],
#  ['Tarjan',
#   '1.046552s',
#   'wall,',
#   '1.030000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.040000s',
#   'CPU',
#   '(99.4%)'],
#  ['Nuutila',
#   '1.077036s',
#   'wall,',
#   '1.080000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.080000s',
#   'CPU',
#   '(100.3%)'],
#  ['Pearce',
#   '1.028590s',
# ...
#   '1.244859s',
#   'wall,',
#   '1.240000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.240000s',
#   'CPU',
#   '(99.6%)'],
#  ['Pearce',
#   '1.271051s',
#   'wall,',
#   '1.270000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.270000s',
#   'CPU',
#   '(99.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.090452_3476.xml', '216K'],
#  ['Tarjan',
#   '1.342244s',
#   'wall,',
#   '1.330000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.350000s',
#   'CPU',
#   '(100.6%)'],
#  ['Nuutila',
#   '1.272775s',
#   'wall,',
#   '1.270000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.270000s',
#   'CPU',
#   '(99.8%)'],
#  ['Pearce',
#   '1.275493s',
#   'wall,',
#   '1.280000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.280000s',
#   'CPU',
#   '(100.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.092965_3567.xml', '220K'],
#  ['Tarjan',
#   '1.398732s',
#   'wall,',
#   '1.380000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.380000s',
#   'CPU',
#   '(98.7%)'],
#  ['Nuutila',
#   '1.338999s',
#   'wall,',
#   '1.330000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.330000s',
#   'CPU',
#   '(99.3%)'],
#  ['Pearce',
#   '1.321561s',
#   'wall,',
#   '1.320000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.320000s',
#   'CPU',
#   '(99.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.095477_3662.xml', '224K'],
#  ['Tarjan',
#   '1.403973s',
#   'wall,',
#   '1.400000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.400000s',
#   'CPU',
#   '(99.7%)'],
#  ['Nuutila',
#   '1.347406s',
#   'wall,',
#   '1.350000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.350000s',
#   'CPU',
#   '(100.2%)'],
#  ['Pearce',
#   '1.318459s',
#   'wall,',
#   '1.310000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.310000s',
#   'CPU',
#   '(99.4%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.097990_3748.xml', '232K'],
#  ['Tarjan',
#   '1.389181s',
#   'wall,',
#   '1.350000s',
#   'user',
#   '+',
#   '0.030000s',
#   'system',
#   '=',
#   '1.380000s',
#   'CPU',
#   '(99.3%)'],
#  ['Nuutila',
#   '1.392925s',
#   'wall,',
#   '1.400000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.400000s',
#   'CPU',
#   '(100.5%)'],
#  ['Pearce',
#   '1.365130s',
#   'wall,',
#   '1.360000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.360000s',
#   'CPU',
#   '(99.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.100503_3836.xml', '236K'],
#  ['Tarjan',
#   '1.450800s',
#   'wall,',
#   '1.410000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.430000s',
#   'CPU',
#   '(98.6%)'],
#  ['Nuutila',
#   '1.433586s',
#   'wall,',
#   '1.430000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.430000s',
#   'CPU',
#   '(99.7%)'],
#  ['Pearce',
#   '1.387011s',
#   'wall,',
#   '1.390000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.390000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.103015_3928.xml', '240K'],
#  ['Tarjan',
#   '1.477979s',
#   'wall,',
#   '1.470000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.470000s',
#   'CPU',
#   '(99.5%)'],
#  ['Nuutila',
#   '1.459798s',
#   'wall,',
#   '1.460000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.460000s',
#   'CPU',
#   '(100.0%)'],
#  ['Pearce',
#   '1.477739s',
#   'wall,',
#   '1.480000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.480000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.105528_4024.xml', '248K'],
#  ['Tarjan',
#   '1.525580s',
#   'wall,',
#   '1.490000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.490000s',
#   'CPU',
#   '(97.7%)'],
#  ['Nuutila',
#   '1.470020s',
#   'wall,',
#   '1.470000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.470000s',
#   'CPU',
#   '(100.0%)'],
#  ['Pearce',
#   '1.449124s',
#   'wall,',
#   '1.450000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.450000s',
#   'CPU',
#   '(100.1%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.108040_4117.xml', '252K'],
#  ['Tarjan',
#   '1.567362s',
#   'wall,',
#   '1.520000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.540000s',
#   'CPU',
#   '(98.3%)'],
#  ['Nuutila',
#   '1.542941s',
#   'wall,',
#   '1.520000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.530000s',
#   'CPU',
#   '(99.2%)'],
#  ['Pearce',
#   '1.509342s',
#   'wall,',
#   '1.490000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.490000s',
#   'CPU',
#   '(98.7%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.110553_4211.xml', '260K'],
#  ['Tarjan',
#   '1.586879s',
#   'wall,',
#   '1.550000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.560000s',
#   'CPU',
#   '(98.3%)'],
#  ['Nuutila',
#   '1.544698s',
#   'wall,',
#   '1.520000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.520000s',
#   'CPU',
#   '(98.4%)'],
#  ['Pearce',
#   '1.594010s',
#   'wall,',
#   '1.570000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.570000s',
#   'CPU',
#   '(98.5%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.113065_4298.xml', '264K'],
#  ['Tarjan',
#   '1.569599s',
#   'wall,',
#   '1.550000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.570000s',
#   'CPU',
#   '(100.0%)'],
#  ['Nuutila',
#   '1.558106s',
#   'wall,',
#   '1.550000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.550000s',
#   'CPU',
#   '(99.5%)'],
#  ['Pearce',
#   '1.548974s',
#   'wall,',
#   '1.550000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.550000s',
#   'CPU',
#   '(100.1%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.115578_4385.xml', '268K'],
#  ['Tarjan',
#   '1.608705s',
#   'wall,',
#   '1.580000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.600000s',
#   'CPU',
#   '(99.5%)'],
#  ['Nuutila',
#   '1.628899s',
#   'wall,',
#   '1.630000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.630000s',
#   'CPU',
#   '(100.1%)'],
#  ['Pearce',
#   '1.602103s',
#   'wall,',
#   '1.600000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.600000s',
#   'CPU',
#   '(99.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.118090_4473.xml', '272K'],
#  ['Tarjan',
#   '1.610944s',
#   'wall,',
#   '1.590000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.600000s',
#   'CPU',
#   '(99.3%)'],
#  ['Nuutila',
#   '1.614108s',
#   'wall,',
#   '1.620000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.620000s',
#   'CPU',
#   '(100.4%)'],
#  ['Pearce',
#   '1.623931s',
#   'wall,',
#   '1.620000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.620000s',
#   'CPU',
#   '(99.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.120603_4561.xml', '280K'],
#  ['Tarjan',
#   '1.690666s',
#   'wall,',
#   '1.660000s',
#   'user',
#   '+',
#   '0.030000s',
#   'system',
#   '=',
#   '1.690000s',
#   'CPU',
#   '(100.0%)'],
#  ['Nuutila',
#   '1.693705s',
#   'wall,',
#   '1.690000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.690000s',
#   'CPU',
#   '(99.8%)'],
#  ['Pearce',
#   '1.711278s',
#   'wall,',
#   '1.710000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.710000s',
#   'CPU',
#   '(99.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.123116_4652.xml', '284K'],
#  ['Tarjan',
#   '1.708956s',
#   'wall,',
#   '1.690000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.710000s',
#   'CPU',
#   '(100.1%)'],
#  ['Nuutila',
#   '1.679108s',
#   'wall,',
#   '1.670000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.670000s',
#   'CPU',
#   '(99.5%)'],
#  ['Pearce',
#   '1.707475s',
#   'wall,',
#   '1.700000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.700000s',
#   'CPU',
#   '(99.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.125628_4743.xml', '288K'],
#  ['Tarjan',
#   '1.735584s',
#   'wall,',
#   '1.730000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.740000s',
#   'CPU',
#   '(100.3%)'],
#  ['Nuutila',
#   '1.708485s',
#   'wall,',
#   '1.710000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.710000s',
#   'CPU',
#   '(100.1%)'],
#  ['Pearce',
#   '1.709187s',
#   'wall,',
#   '1.710000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.710000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.128141_4839.xml', '296K'],
#  ['Tarjan',
#   '1.766535s',
#   'wall,',
#   '1.750000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.760000s',
#   'CPU',
#   '(99.6%)'],
#  ['Nuutila',
#   '1.723836s',
#   'wall,',
#   '1.730000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.730000s',
#   'CPU',
#   '(100.4%)'],
#  ['Pearce',
#   '1.737024s',
#   'wall,',
#   '1.730000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.730000s',
#   'CPU',
#   '(99.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.130653_4928.xml', '300K'],
#  ['Tarjan',
#   '1.802013s',
#   'wall,',
#   '1.770000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.790000s',
#   'CPU',
#   '(99.3%)'],
#  ['Nuutila',
#   '1.765152s',
#   'wall,',
#   '1.770000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.770000s',
#   'CPU',
#   '(100.3%)'],
#  ['Pearce',
#   '1.773199s',
#   'wall,',
#   '1.770000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.770000s',
#   'CPU',
#   '(99.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.133166_5016.xml', '304K'],
#  ['Tarjan',
#   '1.850640s',
#   'wall,',
#   '1.840000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '1.850000s',
#   'CPU',
#   '(100.0%)'],
#  ['Nuutila',
#   '1.798298s',
#   'wall,',
#   '1.800000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.800000s',
#   'CPU',
#   '(100.1%)'],
#  ['Pearce',
#   '1.809192s',
#   'wall,',
#   '1.810000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.810000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.135678_5096.xml', '312K'],
#  ['Tarjan',
#   '1.855434s',
#   'wall,',
#   '1.820000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.840000s',
#   'CPU',
#   '(99.2%)'],
#  ['Nuutila',
#   '1.843196s',
#   'wall,',
#   '1.850000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.850000s',
#   'CPU',
#   '(100.4%)'],
#  ['Pearce',
#   '1.844929s',
#   'wall,',
#   '1.830000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.830000s',
#   'CPU',
#   '(99.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.138191_5183.xml', '316K'],
#  ['Tarjan',
#   '1.916507s',
#   'wall,',
#   '1.900000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.920000s',
#   'CPU',
#   '(100.2%)'],
#  ['Nuutila',
#   '1.877594s',
#   'wall,',
#   '1.870000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.870000s',
#   'CPU',
#   '(99.6%)'],
#  ['Pearce',
#   '1.855100s',
#   'wall,',
#   '1.850000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.850000s',
#   'CPU',
#   '(99.7%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.140704_5267.xml', '320K'],
#  ['Tarjan',
#   '1.954107s',
#   'wall,',
#   '1.920000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.940000s',
#   'CPU',
#   '(99.3%)'],
#  ['Nuutila',
#   '1.895151s',
#   'wall,',
#   '1.880000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.880000s',
#   'CPU',
#   '(99.2%)'],
#  ['Pearce',
#   '1.865555s',
#   'wall,',
#   '1.870000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.870000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.143216_5355.xml', '328K'],
#  ['Tarjan',
#   '1.920735s',
#   'wall,',
#   '1.900000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.920000s',
#   'CPU',
#   '(100.0%)'],
#  ['Nuutila',
#   '1.910761s',
#   'wall,',
#   '1.910000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.910000s',
#   'CPU',
#   '(100.0%)'],
#  ['Pearce',
#   '1.906109s',
#   'wall,',
#   '1.910000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.910000s',
#   'CPU',
#   '(100.2%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.145729_5437.xml', '332K'],
#  ['Tarjan',
#   '1.957660s',
#   'wall,',
#   '1.940000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '1.960000s',
#   'CPU',
#   '(100.1%)'],
#  ['Nuutila',
#   '1.932590s',
#   'wall,',
#   '1.930000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.930000s',
#   'CPU',
#   '(99.9%)'],
#  ['Pearce',
#   '1.904214s',
#   'wall,',
#   '1.900000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.900000s',
#   'CPU',
#   '(99.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.148241_5528.xml', '336K'],
#  ['Tarjan',
#   '2.002068s',
#   'wall,',
#   '1.980000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '2.000000s',
#   'CPU',
#   '(99.9%)'],
#  ['Nuutila',
#   '1.974133s',
#   'wall,',
#   '1.980000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.980000s',
#   'CPU',
#   '(100.3%)'],
#  ['Pearce',
#   '1.973298s',
#   'wall,',
#   '1.970000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.970000s',
#   'CPU',
#   '(99.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.150754_5618.xml', '340K'],
#  ['Tarjan',
#   '2.026603s',
#   'wall,',
#   '2.020000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '2.030000s',
#   'CPU',
#   '(100.2%)'],
#  ['Nuutila',
#   '2.027708s',
#   'wall,',
#   '2.000000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.000000s',
#   'CPU',
#   '(98.6%)'],
#  ['Pearce',
#   '1.993495s',
#   'wall,',
#   '1.990000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '1.990000s',
#   'CPU',
#   '(99.8%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.153266_5704.xml', '348K'],
#  ['Tarjan',
#   '2.120694s',
#   'wall,',
#   '2.070000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '2.090000s',
#   'CPU',
#   '(98.6%)'],
#  ['Nuutila',
#   '2.093003s',
#   'wall,',
#   '2.070000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.070000s',
#   'CPU',
#   '(98.9%)'],
#  ['Pearce',
#   '2.090862s',
#   'wall,',
#   '2.060000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.060000s',
#   'CPU',
#   '(98.5%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.155779_5789.xml', '352K'],
#  ['Tarjan',
#   '2.109412s',
#   'wall,',
#   '2.080000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '2.100000s',
#   'CPU',
#   '(99.6%)'],
#  ['Nuutila',
#   '2.047162s',
#   'wall,',
#   '2.050000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.050000s',
#   'CPU',
#   '(100.1%)'],
#  ['Pearce',
#   '2.098712s',
#   'wall,',
#   '2.090000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.090000s',
#   'CPU',
#   '(99.6%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.158291_5870.xml', '356K'],
#  ['Tarjan',
#   '2.142181s',
#   'wall,',
#   '2.120000s',
#   'user',
#   '+',
#   '0.020000s',
#   'system',
#   '=',
#   '2.140000s',
#   'CPU',
#   '(99.9%)'],
#  ['Nuutila',
#   '2.129117s',
#   'wall,',
#   '2.110000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.110000s',
#   'CPU',
#   '(99.1%)'],
#  ['Pearce',
#   '2.100341s',
#   'wall,',
#   '2.100000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.100000s',
#   'CPU',
#   '(100.0%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.160804_5957.xml', '360K'],
#  ['Tarjan',
#   '2.181527s',
#   'wall,',
#   '2.180000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.180000s',
#   'CPU',
#   '(99.9%)'],
#  ['Nuutila',
#   '2.138544s',
#   'wall,',
#   '2.130000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.130000s',
#   'CPU',
#   '(99.6%)'],
#  ['Pearce',
#   '2.121685s',
#   'wall,',
#   '2.120000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.120000s',
#   'CPU',
#   '(99.9%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.163317_6042.xml', '368K'],
#  ['Tarjan',
#   '2.216677s',
#   'wall,',
#   '2.190000s',
#   'user',
#   '+',
#   '0.010000s',
#   'system',
#   '=',
#   '2.200000s',
#   'CPU',
#   '(99.2%)'],
#  ['Nuutila',
#   '2.204104s',
#   'wall,',
#   '2.200000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.200000s',
#   'CPU',
#   '(99.8%)'],
#  ['Pearce',
#   '2.167671s',
#   'wall,',
#   '2.170000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.170000s',
#   'CPU',
#   '(100.1%)'],
#  ['Components:', '1'],
#  ['Correct:', '1'],
#  ['200_0.165829_6126.xml', '372K'],
#  ['Tarjan',
#   '2.207494s',
#   'wall,',
#   '2.170000s',
#   'user',
#   '+',
#   '0.040000s',
#   'system',
#   '=',
#   '2.210000s',
#   'CPU',
#   '(100.1%)'],
#  ['Nuutila',
#   '2.240909s',
#   'wall,',
#   '2.210000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.210000s',
#   'CPU',
#   '(98.6%)'],
#  ['Pearce',
#   '2.205284s',
#   'wall,',
#   '2.200000s',
#   'user',
#   '+',
#   '0.000000s',
#   'system',
#   '=',
#   '2.200000s',
#   'CPU',
#   '(99.8%)'],
#  ...]

# %%
ll = []
i=0
while i< len(l):
    try:
        v, p, e = l[i][0][:-4].split("_")
        ll.append([int(v), float(p), int(e), float(l[i+1][1][:-1]), float(l[i+2][1][:-1]), float(l[i+3][1][:-1]), int(l[i+4][1]), int(l[i+5][1])])
    except:
        print(l[i][0][:-4].split("_"))
    i+=6
ll[:3]
# Out:
# [[100, 0.0, 0, 0.005653, 0.005533, 0.005335, 100, 1],
#  [100, 0.010101, 101, 0.024712, 0.028359, 0.028065, 96, 1],
#  [100, 0.020202, 200, 0.048088, 0.048199, 0.048177, 41, 1]]

# %%
import csv
f = open("time_first_try.csv", "w")
f.write("vertices,percentage,edges,tarjan,nuutila,pearce,components,correct\n")
w = csv.writer(f)
w.writerows(ll)
f.close()

# %%
import pandas as pd

# %%
t = pd.read_csv("time_first_try.csv")
#t = t[["vertices","percentage","edges", "tarjan", "nuutila", "pearce"]].groupby(by=["vertices","percentage","edges"], as_index=False).mean()

# %%
t["v+e"]=t["vertices"]+t["edges"]

# %%
#for n in ["tarjan", "nuutila", "pearce"]:
#    t[n] = t[n]/t["v+e"]

# %%
t.describe()
# Out:
#           vertices   percentage         edges       tarjan      nuutila  \
# count  1093.000000  1093.000000   1093.000000  1093.000000  1093.000000
# mean    245.196706     0.407909  18811.781336     8.862425     8.725277
# std      65.655909     0.255726  12126.514548     6.718463     6.607192
# min     100.000000     0.000000      0.000000     0.005653     0.005533
# 25%     200.000000     0.195095   8024.000000     3.423012     3.401697
# 50%     300.000000     0.391304  18239.000000     7.193396     7.070789
# 75%     300.000000     0.586399  26988.000000    14.326378    14.121282
# max     300.000000     1.000000  43456.000000    24.081377    23.765367
#
#             pearce           v+e
# count  1093.000000   1093.000000
# mean      8.738764  19056.978042
# std       6.621834  12161.856198
# min       0.005335    100.000000
# 25%       3.366320   8244.000000
# 50%       7.128759  18495.000000
# 75%      14.142496  27288.000000
# max      23.939858  43756.000000

# %%
t[t["v+e"]>25200]
# Out:
#       vertices  percentage  edges     tarjan    nuutila     pearce  \
# 790        300    0.324415  24911  13.424328  13.189869  13.274915
# 491        200    0.982412  25013   8.743804   8.624256   8.596670
# 492        200    0.984925  25048   8.774826   8.503987   8.612761
# 791        300    0.325530  24984  13.470722  13.225380  13.192772
# 493        200    0.987437  25088   8.727388   8.625901   8.609757
# 494        200    0.989950  25118   8.753068   8.636541   8.622350
# 495        200    0.992462  25152   8.794479   8.730295   8.597546
# 792        300    0.326644  25056  13.424756  13.378524  13.224124
# 496        200    0.994975  25183   8.742932   8.652326   8.718250
# 497        200    0.997487  25212   8.761626   8.712411   8.780813
# 793        300    0.327759  25129  13.475041  13.340297  13.399693
# 498        200    1.000000  25246   8.796152   8.594011   8.476837
# 794        300    0.328874  25200  13.573379  13.421577  13.384494
# 795        300    0.329989  25271  13.446220  13.265920  13.134368
# 796        300    0.331104  25345  13.451026  13.178986  13.162513
# 797        300    0.332219  25420  13.357925  13.106267  13.309185
# 798        300    0.333333  25498  13.430407  13.052847  13.249649
# 799        300    0.334448  25574  13.509709  13.241465  13.366542
# 800        300    0.335563  25644  13.658657  13.597395  13.717513
# 801        300    0.336678  25710  13.651308  13.601087  13.603664
# 802        300    0.337793  25778  13.817228  13.596679  13.558130
# 803        300    0.338907  25852  13.984720  13.610677  13.536421
# 804        300    0.340022  25935  13.866709  13.705899  13.577765
# 805        300    0.341137  26001  13.963757  13.665538  13.577283
# 806        300    0.342252  26072  13.901135  13.588187  13.695465
# 807        300    0.343367  26146  13.764756  13.538316  13.791210
# 808        300    0.344482  26224  13.769394  13.551225  13.554134
# 809        300    0.345596  26288  13.828876  13.466940  13.419747
# 810        300    0.346711  26359  13.734248  13.467498  13.800897
# 811        300    0.347826  26429  13.797251  13.615547  13.931768
# ...        ...         ...    ...        ...        ...        ...
# 1063       300    0.628763  41911  22.812405  22.614629  22.646965
# 1064       300    0.629877  41969  22.872703  22.362793  22.562756
# 1065       300    0.630992  42020  23.020758  22.586785  22.582901
# 1066       300    0.632107  42066  23.158832  22.487721  22.324035
# 1067       300    0.633222  42127  22.617336  22.042603  22.268566
# 1068       300    0.634337  42188  22.511808  22.310405  22.352813
# 1069       300    0.635452  42235  22.738949  22.268095  22.539844
# 1070       300    0.636566  42292  22.857772  22.343122  22.406175
# 1071       300    0.637681  42342  22.750157  22.368651  22.145745
# 1072       300    0.638796  42399  22.616147  22.316697  22.666430
# 1073       300    0.639911  42447  22.558191  22.397833  22.557029
# 1074       300    0.641026  42496  22.799789  22.271447  22.637192
# 1075       300    0.642140  42554  23.236746  23.058307  22.772461
# 1076       300    0.643255  42601  23.346683  23.418269  22.950707
# 1077       300    0.644370  42649  23.266606  23.121069  23.226726
# 1078       300    0.645485  42716  23.589769  22.924383  23.091529
# 1079       300    0.646600  42767  23.127794  22.847330  22.929203
# 1080       300    0.647715  42818  23.298337  22.813175  22.758939
# 1081       300    0.648829  42863  22.918958  22.728143  22.686691
# 1082       300    0.649944  42918  23.423668  23.092637  23.137789
# 1083       300    0.651059  42979  23.565867  23.067511  23.298844
# 1084       300    0.652174  43032  23.390693  23.123567  23.050910
# 1085       300    0.653289  43088  23.476470  23.122651  23.252216
# 1086       300    0.654404  43146  23.439872  22.582288  22.794344
# 1087       300    0.655518  43200  23.481498  22.766490  22.984583
# 1088       300    0.656633  43244  23.432152  22.785202  23.043579
# 1089       300    0.657748  43296  23.428857  22.881281  23.165181
# 1090       300    0.658863  43347  23.279337  22.648015  22.773714
# 1091       300    0.659978  43399  24.081377  23.765367  23.939858
# 1092       300    0.661093  43456  23.439706  22.785439  22.900601
#
#       components  correct    v+e
# 790            1        1  25211
# 491            1        1  25213
# 492            1        1  25248
# 791            1        1  25284
# 493            1        1  25288
# 494            1        1  25318
# 495            1        1  25352
# 792            1        1  25356
# 496            1        1  25383
# 497            1        1  25412
# 793            1        1  25429
# 498            1        1  25446
# 794            1        1  25500
# 795            1        1  25571
# 796            1        1  25645
# 797            1        1  25720
# 798            1        1  25798
# 799            1        1  25874
# 800            1        1  25944
# 801            1        1  26010
# 802            1        1  26078
# 803            1        1  26152
# 804            1        1  26235
# 805            1        1  26301
# 806            1        1  26372
# 807            1        1  26446
# 808            1        1  26524
# 809            1        1  26588
# 810            1        1  26659
# 811            1        1  26729
# ...          ...      ...    ...
# 1063           1        1  42211
# 1064           1        1  42269
# 1065           1        1  42320
# 1066           1        1  42366
# 1067           1        1  42427
# 1068           1        1  42488
# 1069           1        1  42535
# 1070           1        1  42592
# 1071           1        1  42642
# 1072           1        1  42699
# 1073           1        1  42747
# 1074           1        1  42796
# 1075           1        1  42854
# 1076           1        1  42901
# 1077           1        1  42949
# 1078           1        1  43016
# 1079           1        1  43067
# 1080           1        1  43118
# 1081           1        1  43163
# 1082           1        1  43218
# 1083           1        1  43279
# 1084           1        1  43332
# 1085           1        1  43388
# 1086           1        1  43446
# 1087           1        1  43500
# 1088           1        1  43544
# 1089           1        1  43596
# 1090           1        1  43647
# 1091           1        1  43699
# 1092           1        1  43756
#
# [311 rows x 9 columns]

# %%
t = t.sort_values(by=["v+e","edges","vertices"])
t.plot(x="v+e", y=["tarjan","nuutila","pearce"],figsize=(20,20), subplots=True)
# Out:
# /usr/lib64/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f14a8a01d30>],
#       dtype=object)

# %%
t[t["vertices"]==100].plot(x="v+e", y=["tarjan","nuutila","pearce"],figsize=(10,10))
t[t["vertices"]==200].plot(x="v+e", y=["tarjan","nuutila","pearce"],figsize=(10,10))
t[t["vertices"]==300].plot(x="v+e", y=["tarjan","nuutila","pearce"],figsize=(10,10))
# Out:
# /usr/lib64/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
from scipy.interpolate import griddata
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

df=t
x1 = np.linspace(df['vertices'].min(), df['vertices'].max(), len(df['vertices'].unique()))
y1 = np.linspace(df['edges'].min(), df['edges'].max(), len(df['edges'].unique()))

"""
x, y via meshgrid for vectorized evaluation of
2 scalar/vector fields over 2-D grids, given
one-dimensional coordinate arrays x1, x2,..., xn.
"""

x2, y2 = np.meshgrid(x1, y1)

# Interpolate unstructured D-dimensional data.
z2 = griddata((df['vertices'], df['edges']), df['tarjan'], (x2, y2), method='cubic')

# Ready to plot
fig = plt.figure(figsize=(20,20))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(x2, y2, z2, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
#ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title('Meshgrid Created from 3 1D Arrays')

plt.show()

#Modified example using <code>DataFrame</code> input
# Out:
# /usr/lib64/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /usr/lib64/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# /usr/lib64/python3.6/site-packages/matplotlib/colors.py:489: RuntimeWarning: invalid value encountered in less
#   np.copyto(xa, -1, where=xa < 0.0)

# %%
np.sin(t["v+e"])
# Out:
# 0      -0.506366
# 100    -0.873297
# 1      -0.061890
# 2      -0.999756
# 101    -0.999756
# 499    -0.999756
# 3       0.916534
# 102    -0.017732
# 500    -0.850919
# 4      -0.696102
# 103    -0.467772
# 501    -0.467772
# 5      -0.580562
# 104     0.044182
# 502     0.044182
# 6      -0.956394
# 105    -0.412173
# 503    -0.412173
# 7       0.773929
# 504     0.105928
# 106    -0.779504
# 8      -0.354854
# 107     0.483371
# 505     0.997803
# 9       0.451945
# 108    -0.114875
# 506    -0.026461
# 10     -0.756743
# 109     0.988018
# 507    -0.529006
#           ...
# 1063    0.532123
# 1064    0.904051
# 1065    0.384473
# 1066   -0.998634
# 1067    0.207273
# 1068    0.891639
# 1069   -0.828858
# 1070   -0.989878
# 1071   -0.917962
# 1072   -0.999056
# 1073    0.606171
# 1074    0.940763
# 1075    0.448769
# 1076   -0.555760
# 1077   -0.282916
# 1078    0.967053
# 1079    0.888327
# 1080    0.351498
# 1081   -0.611957
# 1082    0.777157
# 1083    0.407399
# 1084   -0.012529
# 1085    0.510820
# 1086   -0.792681
# 1087    0.998036
# 1088    0.998989
# 1089   -0.118467
# 1090   -0.753430
# 1091   -0.525933
# 1092   -0.102300
# Name: v+e, Length: 1093, dtype: float64
